# %%
# %matplotlib inline
import missingno as msno
import pandas as pd

data_ori = pd.read_csv("data_raw_traininputs.csv")
msno.matrix(data_ori)

# %%
data_header.isnull().sum()
# Out:
# column1     862
# column2     862
# column3     862
# column4     862
# column5     862
# column6     862
# column7     862
# column8     862
# column9     862
# column10    862
# column11    862
# column12    862
# column13    862
# column14    862
# column15    862
# column16    862
# column17    862
# column18    862
# column19    862
# column20    862
# column21    862
# column22    862
# column23    862
# column24    862
# column25    862
# column26    862
# column27    862
# column28    862
# column29    862
# column30    862
#            ...
# column48    206
# column49    206
# column50    206
# column51    206
# column52    206
# column53    206
# column54    206
# column55    206
# column56    206
# column57    206
# column58    206
# column59    206
# column60    206
# column61    206
# column62    206
# column63    206
# column64    206
# column65    206
# column66    206
# column67    206
# column68    206
# column69    206
# column70    206
# column71    206
# ...

# %%
data_header = pd.read_csv("data_raw_testinputs_header.csv")
msno.bar(data_header.sample(1000))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-96563f5d0dd5> in <module>()
# ----> 1 data_header = pd.read_csv("data_raw_testinputs_header.csv")
#       2 msno.bar(data_header.sample(1000))
#
# NameError: name 'pd' is not defined

# %%
data_header = pd.read_csv("data_raw_testinputs_header.csv")
msno.heatmap(data_header)

# %%
msno.dendrogram(data_header)
